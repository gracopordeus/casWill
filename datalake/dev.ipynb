# %%
import sys
sys.path.append('/home/r42/caseWill')
from utils.connections import duckdb_postgres_query, postgres_query

# %%
duckdb_postgres_query("select 'oi'").df()
# Out:
#   'oi'
# 0   oi

# %%
duckdb_postgres_query("SHOW schemas").df()
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 duckdb_postgres_query("SHOW schemas").df()
#
# File ~/caseWill/utils/connections.py:81, in duckdb_postgres_query(query, db)
#      80 def duckdb_postgres_query(query:str, db=db):
# ---> 81     return db.sql("USE postgres; "+ query)
#
# CatalogException: Catalog Error: Table with name schemas does not exist!
# Did you mean "memory.information_schema.schemata"?

# %%
duckdb_postgres_query("select * from bronze.customer").df()
# Out:
#     entry_date  surrogate_key          full_name birth_date  \
# 0   2022-11-18           1000     Sophie Peixoto 1981-05-18
# 1   2022-11-05           2000      Miguel Campos 1988-09-04
# 2   2023-01-01           3000      Bryan Cardoso 1992-04-14
# 3   2023-03-21           4000      Nicolas Viana 1984-06-08
# 4   2022-09-26           5000  Heitor Cavalcanti 1993-06-23
# ..         ...            ...                ...        ...
# 995 2023-07-03         496000      Bruna da Mota 1998-03-13
# 996 2023-07-26         497000    Sra. Isis Costa 1990-10-26
# 997 2023-03-19         498000       Noah da Cruz 1991-05-15
# 998 2022-12-01         499000     Kamilly Farias 1988-06-21
# 999 2022-12-01         500000         Davi Sales 1990-03-31
#
#                 uf_name  uf                   street_name
# 0                 Goiás  GO  Passarela Stephany Jesus, 45
# 1              Amazonas  AM  Recanto Maitê Nascimento, 81
# 2             Tocantins  TO           Viaduto de Lima, 49
# ...
